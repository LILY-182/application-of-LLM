# %% [markdown]
# <a href="https://colab.research.google.com/github/LILY-182/application-of-LLM/blob/main/LLM_applications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## large language models applications
# in this notebook we will explore applications of large language models using the transformer libreary
#
# 1. text summurization

# %%
from transformers import pipeline
from warnings import filterwarnings
filterwarnings('ignore')
summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
text = """ The emergence of artificial intelligence has
reshaped sectors and drastically altered our interaction with
technology. AI-powered solutions are now ubiquitous in
various sectors, including healthcare, finance, and
transportation. These advancements have led to improved
efficiency, accuracy, and innovation. However, concerns
about AI ethics, bias, and job displacement remain. It is
essential to address these challenges while harnessing the
potential of AI for positive societal impact."""

# %%
summary = summarizer(text, max_length=50, min_length=30, do_sample=False)
print(summary[0]['summary_text'])
# Out:
#  The emergence of artificial intelligence has drastically altered our interaction with technology . AI-powered solutions are now ubiquitous in various sectors, including healthcare, finance, and transportation . However, concerns about AI ethics, bias, and job displacement remain .

# %% [markdown]
# 2. TEXT GENERATION

# %%
from transformers import pipeline
from warnings import filterwarnings
filterwarnings('ignore')

generator = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 6c0e608 (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
prompt = "Once upon a time, in a faraway kingdom,"

# %%
generated_text = generator(prompt, max_length=100,
do_sample=True, temperature=0.7)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(generated_text[0]['generated_text'])
# Out:
# Once upon a time, in a faraway kingdom, a god named J'onk has taken over. As the king of worlds, J'onk has also taken over the world of the living, creating the world of the living, and making the living into their own gods. He is a god of death, and the living are to die, but he is not a god of rebirth. He is the god of death, and then there is the god of rebirth. For example,

# %% [markdown]
# 3. CODE COMPLETION

# %%
from transformers import pipeline
from warnings import filterwarnings
filterwarnings('ignore')

# %%
#load a pre trained code genration code
code_completion = pipeline("text-generation", model="Salesforce/codegen-350M-mono")
# Out:
# config.json:   0%|          | 0.00/999 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/797M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/240 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]

# %%
prompt = "def check_leap_year(year):"

# %%
# Complete code snippet
completed_code = code_completion(prompt, max_length=200, num_return_sequences=1)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
# Print the completed code snippet
print(completed_code[0]['generated_text'])
# Out:
# def check_leap_year(year):
#     if year % 4 == 0:
#         if year % 100 == 0:
#             if year % 400 == 0:
#                 return True
#             else:
#                 return False
#         else:
#             return True
#     else:
#         return False
#
# if __name__ == '__main__':
#     print(check_leap_year(2016))
#     print(check_leap_year(2015))
#     print(check_leap_year(2017))

# %%
#big tech companies have trained models with high capabilities
#building conversational chat bot using google gemini
